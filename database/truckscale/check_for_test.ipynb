# %%
import pandas as pd

# %%
df = pd.read_excel("Weighing_TruckWeighing.xlsx")

# %%
empty_weight_out = df[df['weightInTime'].notnull() & df['weightOutTime'].isnull()]

# แสดงผลลัพธ์
print(len(empty_weight_out))
print(empty_weight_out.head())
# Out:
# 41
#                                     row_key cardCode carRegister  \
# 13294  019f703f-ff02-7a90-8366-882616363b56   NOCARD  PSS74-5284
# 16455  019f9898-7703-79f9-85cc-028f7872f805   002408     71-2482
# 22617  019feee4-b189-7fcc-a4fe-5b93f0d1f547   NOCARD     62-6059
# 29077  01a027f3-881b-721e-a818-230d799eda39   NOCARD     71-1596
# 29874  01a0328d-396b-7027-b5f5-2bc924e2bc3b   NOCARD     70-5717
#
#                                    province  \
# 13294  B1743181-962B-437F-B88F-B5032D4D360A
# 16455  51B9DC93-D605-4EC4-86EB-0D6C973462C0
# 22617  1DA56326-76A7-4BB0-A032-D9A15A8FDA39
# 29077                                 ERROR
# 29874  592CA903-4E81-4205-9FC7-A7A5877EF3D5
#
#                                 vehicleType  \
# 13294  16DF8FDF-26F3-4C04-95FF-C7236158F9A7
# 16455  6A9C804A-4CA4-476D-AE59-F38891EDFE25
# 22617  8D3588F0-29C8-4E72-A04D-D92F73136452
# 29077  5BBA80AE-D454-4D82-B2E0-EE566ABDCA01
# 29874  6A9C804A-4CA4-476D-AE59-F38891EDFE25
#
# ...

# %%
empty_weight_out.to_excel('pending_weight_out.xlsx', index=False)

print("ส่งออกไฟล์ Excel สำเร็จ! จำนวนแถว:", len(empty_weight_out))
# Out:
# ส่งออกไฟล์ Excel สำเร็จ! จำนวนแถว: 41
